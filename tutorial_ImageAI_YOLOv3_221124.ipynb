# %% [markdown]
# ## References
# - Ryan Wells (2022) Object Detection from Videos with YOLO using Python. https://wellsr.com/python/object-detection-from-videos-with-yolo/
# - ImageAI (2021) Video and Live-Feed Detection and Analysis. https://imageai.readthedocs.io/en/latest/video/

# %%
from imageai.Detection import VideoObjectDetection

# %%
detector = VideoObjectDetection()

# %%
# use the pre-trained YOLOv3 model
detector.setModelTypeAsYOLOv3()
detector.setModelPath("yolo.h5")

# %%
detector.loadModel()

# %% [markdown]
# * <code>frames_per_second</code>: This parameters allows you to set your desired frames per second for the detected video that will be saved.
# * <code>minimum_percentage_probability</code>: This parameter is used to determine the integrity of the detection results. Lowering the value shows more objects while increasing the value ensures objects with the highest accuracy are detected. The default value is 50.

# %%
video_path = detector.detectObjectsFromVideo(input_file_path="input_video.mp4", output_file_path="output_video",
                                             frames_per_second=15, log_progress=True,
                                             per_frame_function=forFrame)
# Out:
# Processing Frame :  1
# Processing Frame :  2
# Processing Frame :  3
# Processing Frame :  4
# Processing Frame :  5
# Processing Frame :  6
# Processing Frame :  7
# Processing Frame :  8
# Processing Frame :  9
# Processing Frame :  10
# Processing Frame :  11
# Processing Frame :  12
# Processing Frame :  13
# Processing Frame :  14
# Processing Frame :  15
# Processing Frame :  16
# Processing Frame :  17
# Processing Frame :  18
# Processing Frame :  19
# Processing Frame :  20
# Processing Frame :  21
# Processing Frame :  22
# Processing Frame :  23
# Processing Frame :  24
# Processing Frame :  25
# Processing Frame :  26
# Processing Frame :  27
# Processing Frame :  28
# Processing Frame :  29
# Processing Frame :  30
# Processing Frame :  31
# Processing Frame :  32
# Processing Frame :  33
# Processing Frame :  34
# Processing Frame :  35
# Processing Frame :  36
# Processing Frame :  37
# Processing Frame :  38
# Processing Frame :  39
# Processing Frame :  40
# Processing Frame :  41
# Processing Frame :  42
# Processing Frame :  43
# Processing Frame :  44
# Processing Frame :  45
# Processing Frame :  46
# Processing Frame :  47
# Processing Frame :  48
# Processing Frame :  49
# Processing Frame :  50
# Processing Frame :  51
# Processing Frame :  52
# Processing Frame :  53
# Processing Frame :  54
# Processing Frame :  55
# Processing Frame :  56
# Processing Frame :  57
# Processing Frame :  58
# Processing Frame :  59
# Processing Frame :  60
# Processing Frame :  61
# Processing Frame :  62
# Processing Frame :  63
# Processing Frame :  64
# Processing Frame :  65
# Processing Frame :  66
# Processing Frame :  67
# Processing Frame :  68
# Processing Frame :  69
# Processing Frame :  70
# Processing Frame :  71
# Processing Frame :  72
# Processing Frame :  73
# Processing Frame :  74
# Processing Frame :  75
# Processing Frame :  76
# Processing Frame :  77
# Processing Frame :  78
# Processing Frame :  79
# Processing Frame :  80
# Processing Frame :  81
# Processing Frame :  82
# Processing Frame :  83
# Processing Frame :  84
# Processing Frame :  85
# Processing Frame :  86
# Processing Frame :  87
# Processing Frame :  88
# Processing Frame :  89
# Processing Frame :  90
# Processing Frame :  91
# Processing Frame :  92
# Processing Frame :  93
# Processing Frame :  94
# Processing Frame :  95
# Processing Frame :  96
# Processing Frame :  97
# Processing Frame :  98
# Processing Frame :  99
# Processing Frame :  100
# Processing Frame :  101
# Processing Frame :  102
# Processing Frame :  103
# Processing Frame :  104
# Processing Frame :  105
# Processing Frame :  106
# Processing Frame :  107
# Processing Frame :  108
# Processing Frame :  109
# Processing Frame :  110
# Processing Frame :  111
# Processing Frame :  112
# Processing Frame :  113
# Processing Frame :  114
# Processing Frame :  115
# Processing Frame :  116
# Processing Frame :  117
# Processing Frame :  118
# Processing Frame :  119
# Processing Frame :  120
# Processing Frame :  121
# Processing Frame :  122
# Processing Frame :  123
# Processing Frame :  124
# Processing Frame :  125
# Processing Frame :  126
# Processing Frame :  127
# Processing Frame :  128
# Processing Frame :  129
# Processing Frame :  130
# Processing Frame :  131
# Processing Frame :  132
# Processing Frame :  133
# Processing Frame :  134
# Processing Frame :  135
# Processing Frame :  136
# Processing Frame :  137
# Processing Frame :  138
# Processing Frame :  139
# Processing Frame :  140
# Processing Frame :  141
# Processing Frame :  142
# Processing Frame :  143
# Processing Frame :  144
# Processing Frame :  145
# Processing Frame :  146
# Processing Frame :  147
# Processing Frame :  148
# Processing Frame :  149
# Processing Frame :  150
# Processing Frame :  151
# Processing Frame :  152
# Processing Frame :  153
# Processing Frame :  154
# Processing Frame :  155
# Processing Frame :  156
# Processing Frame :  157
# Processing Frame :  158
# Processing Frame :  159
# Processing Frame :  160
# Processing Frame :  161
# Processing Frame :  162
# Processing Frame :  163
# Processing Frame :  164
# Processing Frame :  165
# Processing Frame :  166
# Processing Frame :  167
# Processing Frame :  168
# Processing Frame :  169
# Processing Frame :  170
# Processing Frame :  171
# Processing Frame :  172
# Processing Frame :  173
# Processing Frame :  174
# Processing Frame :  175
# Processing Frame :  176
# Processing Frame :  177
# Processing Frame :  178
# Processing Frame :  179
# Processing Frame :  180
# Processing Frame :  181
# Processing Frame :  182
# Processing Frame :  183
# Processing Frame :  184
# Processing Frame :  185

# %% [markdown]
# * <code><b>per_frame_function</b></code>: This parameter allows you to parse in the name of a function you define. Then, for every frame of the video that is detected, the function will be parsed into the parameter will be executed and and analytical data of the video will be parsed into the function. The data returned can be visualized or saved in a NoSQL database for future processing and visualization.

# %%
def forFrame(frame_number, output_array, output_count):
    print("FOR FRAME ", frame_number)
    print("Output for each object : ", output_array)
    print("Output count for unique objects : ", output_count)
    print("------------END OF A FRAME --------------")

# %%
video_path = detector.detectObjectsFromVideo(input_file_path="input_video.mp4", output_file_path="output_video",
                                             frames_per_second=30, log_progress=True,
                                             per_frame_function=forFrame)
# Out:
# Processing Frame :  1
# FOR FRAME  1
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 51.41030550003052, 'box_points': [125, 157, 178, 248]}, {'name': 'person', 'percentage_probability': 99.66697096824646, 'box_points': [137, 122, 274, 404]}, {'name': 'person', 'percentage_probability': 99.41209554672241, 'box_points': [380, 191, 445, 387]}]
# Output count for unique objects :  {'backpack': 1, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  2
# FOR FRAME  2
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 51.18616819381714, 'box_points': [125, 157, 178, 248]}, {'name': 'person', 'percentage_probability': 99.64926838874817, 'box_points': [137, 122, 274, 404]}, {'name': 'person', 'percentage_probability': 99.4120717048645, 'box_points': [380, 191, 445, 387]}]
# Output count for unique objects :  {'backpack': 1, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  3
# FOR FRAME  3
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.61333274841309, 'box_points': [133, 119, 278, 400]}, {'name': 'person', 'percentage_probability': 99.79525804519653, 'box_points': [375, 195, 438, 384]}]
# Output count for unique objects :  {'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  4
# FOR FRAME  4
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.81123805046082, 'box_points': [135, 118, 284, 403]}, {'name': 'person', 'percentage_probability': 99.59298968315125, 'box_points': [368, 190, 428, 389]}]
# Output count for unique objects :  {'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  5
# FOR FRAME  5
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.9245822429657, 'box_points': [141, 123, 283, 403]}, {'name': 'person', 'percentage_probability': 99.0419864654541, 'box_points': [360, 188, 421, 388]}]
# Output count for unique objects :  {'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  6
# FOR FRAME  6
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.69872236251831, 'box_points': [141, 118, 289, 408]}, {'name': 'person', 'percentage_probability': 99.39795136451721, 'box_points': [355, 192, 416, 386]}, {'name': 'backpack', 'percentage_probability': 59.531188011169434, 'box_points': [387, 210, 421, 264]}]
# Output count for unique objects :  {'person': 2, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  7
# FOR FRAME  7
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.71203804016113, 'box_points': [141, 118, 289, 408]}, {'name': 'person', 'percentage_probability': 99.38673377037048, 'box_points': [355, 193, 416, 385]}, {'name': 'backpack', 'percentage_probability': 58.79096984863281, 'box_points': [387, 209, 421, 264]}]
# Output count for unique objects :  {'person': 2, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  8
# FOR FRAME  8
# Output for each object :  [{'name': 'person', 'percentage_probability': 83.72564315795898, 'box_points': [137, 136, 220, 399]}, {'name': 'person', 'percentage_probability': 96.42917513847351, 'box_points': [190, 123, 303, 405]}, {'name': 'person', 'percentage_probability': 99.50583577156067, 'box_points': [351, 195, 412, 384]}, {'name': 'backpack', 'percentage_probability': 80.63133358955383, 'box_points': [383, 210, 414, 266]}]
# Output count for unique objects :  {'person': 3, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  9
# FOR FRAME  9
# Output for each object :  [{'name': 'person', 'percentage_probability': 90.76057076454163, 'box_points': [119, 138, 196, 392]}, {'name': 'person', 'percentage_probability': 98.42329025268555, 'box_points': [179, 115, 308, 408]}, {'name': 'person', 'percentage_probability': 99.54546093940735, 'box_points': [341, 194, 413, 385]}]
# Output count for unique objects :  {'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  10
# FOR FRAME  10
# Output for each object :  [{'name': 'person', 'percentage_probability': 98.60279560089111, 'box_points': [125, 148, 221, 388]}, {'name': 'person', 'percentage_probability': 99.56120252609253, 'box_points': [187, 115, 310, 407]}, {'name': 'person', 'percentage_probability': 99.46905374526978, 'box_points': [325, 194, 413, 385]}, {'name': 'backpack', 'percentage_probability': 88.85194063186646, 'box_points': [184, 157, 222, 237]}, {'name': 'backpack', 'percentage_probability': 57.90506601333618, 'box_points': [368, 214, 407, 269]}]
# Output count for unique objects :  {'person': 3, 'backpack': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  11
# FOR FRAME  11
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.33620691299438, 'box_points': [115, 137, 199, 394]}, {'name': 'person', 'percentage_probability': 99.66416358947754, 'box_points': [183, 115, 311, 403]}, {'name': 'person', 'percentage_probability': 99.55279231071472, 'box_points': [323, 195, 410, 384]}, {'name': 'backpack', 'percentage_probability': 85.76077222824097, 'box_points': [188, 156, 231, 237]}]
# Output count for unique objects :  {'person': 3, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  12
# FOR FRAME  12
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.35649633407593, 'box_points': [115, 137, 199, 394]}, {'name': 'person', 'percentage_probability': 99.66925382614136, 'box_points': [183, 114, 311, 403]}, {'name': 'person', 'percentage_probability': 99.55344200134277, 'box_points': [323, 195, 410, 384]}, {'name': 'backpack', 'percentage_probability': 84.98327136039734, 'box_points': [188, 156, 231, 237]}]
# Output count for unique objects :  {'person': 3, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  13
# FOR FRAME  13
# Output for each object :  [{'name': 'person', 'percentage_probability': 98.97107481956482, 'box_points': [106, 140, 199, 390]}, {'name': 'person', 'percentage_probability': 99.67210292816162, 'box_points': [198, 107, 315, 409]}, {'name': 'person', 'percentage_probability': 99.25225973129272, 'box_points': [321, 194, 410, 386]}, {'name': 'backpack', 'percentage_probability': 63.18640112876892, 'box_points': [197, 159, 238, 235]}]
# Output count for unique objects :  {'person': 3, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  14
# FOR FRAME  14
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.42308068275452, 'box_points': [98, 137, 189, 386]}, {'name': 'person', 'percentage_probability': 99.58680272102356, 'box_points': [212, 113, 325, 403]}, {'name': 'person', 'percentage_probability': 54.06966209411621, 'box_points': [0, 160, 24, 410]}, {'name': 'person', 'percentage_probability': 98.73434901237488, 'box_points': [321, 198, 410, 385]}, {'name': 'backpack', 'percentage_probability': 73.85637164115906, 'box_points': [203, 151, 246, 233]}, {'name': 'backpack', 'percentage_probability': 53.49090099334717, 'box_points': [350, 212, 389, 267]}]
# Output count for unique objects :  {'person': 4, 'backpack': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  15
# FOR FRAME  15
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.34823513031006, 'box_points': [76, 137, 173, 382]}, {'name': 'person', 'percentage_probability': 99.61900115013123, 'box_points': [218, 111, 325, 403]}, {'name': 'person', 'percentage_probability': 98.21923971176147, 'box_points': [319, 195, 393, 382]}, {'name': 'backpack', 'percentage_probability': 73.99910092353821, 'box_points': [212, 148, 255, 237]}]
# Output count for unique objects :  {'person': 3, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  16
# FOR FRAME  16
# Output for each object :  [{'name': 'person', 'percentage_probability': 53.045421838760376, 'box_points': [0, 16, 86, 438]}, {'name': 'person', 'percentage_probability': 99.7271716594696, 'box_points': [63, 140, 168, 382]}, {'name': 'person', 'percentage_probability': 99.59017634391785, 'box_points': [226, 109, 338, 409]}, {'name': 'person', 'percentage_probability': 99.19856786727905, 'box_points': [319, 195, 387, 381]}, {'name': 'backpack', 'percentage_probability': 79.90078926086426, 'box_points': [216, 156, 261, 238]}]
# Output count for unique objects :  {'person': 4, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  17
# FOR FRAME  17
# Output for each object :  [{'name': 'person', 'percentage_probability': 53.28734517097473, 'box_points': [0, 16, 86, 438]}, {'name': 'person', 'percentage_probability': 99.72257018089294, 'box_points': [64, 140, 168, 382]}, {'name': 'person', 'percentage_probability': 99.5905876159668, 'box_points': [226, 109, 338, 409]}, {'name': 'person', 'percentage_probability': 99.19613003730774, 'box_points': [319, 195, 387, 382]}, {'name': 'backpack', 'percentage_probability': 80.10904788970947, 'box_points': [216, 156, 261, 238]}]
# Output count for unique objects :  {'person': 4, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  18
# FOR FRAME  18
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 77.78921723365784, 'box_points': [224, 157, 275, 247]}, {'name': 'person', 'percentage_probability': 99.513840675354, 'box_points': [52, 146, 166, 380]}, {'name': 'person', 'percentage_probability': 99.64948296546936, 'box_points': [230, 113, 345, 408]}, {'name': 'person', 'percentage_probability': 93.0516242980957, 'box_points': [322, 201, 380, 378]}]
# Output count for unique objects :  {'backpack': 1, 'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  19
# FOR FRAME  19
# Output for each object :  [{'name': 'person', 'percentage_probability': 96.87276482582092, 'box_points': [0, 39, 86, 425]}, {'name': 'person', 'percentage_probability': 98.33623170852661, 'box_points': [62, 148, 160, 382]}, {'name': 'person', 'percentage_probability': 99.52247142791748, 'box_points': [239, 117, 373, 405]}, {'name': 'backpack', 'percentage_probability': 82.68768787384033, 'box_points': [230, 157, 273, 240]}]
# Output count for unique objects :  {'person': 3, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  20
# FOR FRAME  20
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 66.56466126441956, 'box_points': [231, 163, 284, 247]}, {'name': 'person', 'percentage_probability': 97.26828932762146, 'box_points': [2, 41, 91, 422]}, {'name': 'person', 'percentage_probability': 99.35832619667053, 'box_points': [60, 150, 164, 383]}, {'name': 'person', 'percentage_probability': 99.92696046829224, 'box_points': [243, 123, 389, 405]}, {'name': 'handbag', 'percentage_probability': 54.323720932006836, 'box_points': [236, 160, 283, 243]}]
# Output count for unique objects :  {'backpack': 1, 'person': 3, 'handbag': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  21
# FOR FRAME  21
# Output for each object :  [{'name': 'person', 'percentage_probability': 98.20334911346436, 'box_points': [4, 36, 103, 420]}, {'name': 'person', 'percentage_probability': 98.8024353981018, 'box_points': [75, 146, 162, 388]}, {'name': 'person', 'percentage_probability': 99.97428059577942, 'box_points': [244, 119, 396, 405]}, {'name': 'backpack', 'percentage_probability': 85.89246273040771, 'box_points': [249, 155, 289, 244]}]
# Output count for unique objects :  {'person': 3, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  22
# FOR FRAME  22
# Output for each object :  [{'name': 'person', 'percentage_probability': 98.29795360565186, 'box_points': [4, 36, 104, 419]}, {'name': 'person', 'percentage_probability': 98.86263012886047, 'box_points': [75, 146, 162, 388]}, {'name': 'person', 'percentage_probability': 99.97407793998718, 'box_points': [244, 119, 396, 405]}, {'name': 'backpack', 'percentage_probability': 86.34095788002014, 'box_points': [249, 155, 289, 244]}]
# Output count for unique objects :  {'person': 3, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  23
# FOR FRAME  23
# Output for each object :  [{'name': 'person', 'percentage_probability': 93.25811862945557, 'box_points': [3, 47, 111, 410]}, {'name': 'person', 'percentage_probability': 52.41931080818176, 'box_points': [77, 128, 162, 394]}, {'name': 'person', 'percentage_probability': 99.76786375045776, 'box_points': [260, 130, 409, 400]}, {'name': 'backpack', 'percentage_probability': 70.29041647911072, 'box_points': [260, 159, 301, 245]}]
# Output count for unique objects :  {'person': 3, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  24
# FOR FRAME  24
# Output for each object :  [{'name': 'person', 'percentage_probability': 94.46287751197815, 'box_points': [17, 36, 145, 418]}, {'name': 'person', 'percentage_probability': 99.94457364082336, 'box_points': [253, 128, 416, 398]}, {'name': 'backpack', 'percentage_probability': 63.50619196891785, 'box_points': [266, 158, 308, 245]}, {'name': 'handbag', 'percentage_probability': 56.9767951965332, 'box_points': [266, 158, 308, 245]}]
# Output count for unique objects :  {'person': 2, 'backpack': 1, 'handbag': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  25
# FOR FRAME  25
# Output for each object :  [{'name': 'person', 'percentage_probability': 93.66958737373352, 'box_points': [0, 18, 115, 437]}, {'name': 'person', 'percentage_probability': 99.94482398033142, 'box_points': [264, 126, 419, 401]}, {'name': 'backpack', 'percentage_probability': 76.33771896362305, 'box_points': [275, 158, 319, 244]}]
# Output count for unique objects :  {'person': 2, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  26
# FOR FRAME  26
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 63.12345862388611, 'box_points': [283, 147, 343, 262]}, {'name': 'person', 'percentage_probability': 96.6663122177124, 'box_points': [13, 13, 142, 444]}, {'name': 'person', 'percentage_probability': 99.93186593055725, 'box_points': [272, 119, 426, 407]}]
# Output count for unique objects :  {'backpack': 1, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  27
# FOR FRAME  27
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 64.35590386390686, 'box_points': [282, 147, 343, 262]}, {'name': 'person', 'percentage_probability': 96.60495519638062, 'box_points': [13, 13, 142, 445]}, {'name': 'person', 'percentage_probability': 99.9366283416748, 'box_points': [272, 119, 426, 407]}]
# Output count for unique objects :  {'backpack': 1, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  28
# FOR FRAME  28
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 75.63784718513489, 'box_points': [291, 158, 347, 259]}, {'name': 'person', 'percentage_probability': 98.37502241134644, 'box_points': [5, 21, 145, 439]}, {'name': 'person', 'percentage_probability': 99.88411664962769, 'box_points': [273, 116, 424, 407]}]
# Output count for unique objects :  {'backpack': 1, 'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  29
# FOR FRAME  29
# Output for each object :  [{'name': 'person', 'percentage_probability': 94.1713035106659, 'box_points': [15, 10, 149, 447]}, {'name': 'person', 'percentage_probability': 95.75311541557312, 'box_points': [257, 187, 317, 365]}, {'name': 'person', 'percentage_probability': 99.91156458854675, 'box_points': [275, 115, 424, 405]}]
# Output count for unique objects :  {'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  30
# FOR FRAME  30
# Output for each object :  [{'name': 'person', 'percentage_probability': 98.28452467918396, 'box_points': [11, 13, 182, 457]}, {'name': 'person', 'percentage_probability': 63.11953067779541, 'box_points': [4, 37, 104, 413]}, {'name': 'person', 'percentage_probability': 62.82358765602112, 'box_points': [98, 80, 190, 429]}, {'name': 'person', 'percentage_probability': 99.63222742080688, 'box_points': [308, 115, 426, 411]}, {'name': 'person', 'percentage_probability': 98.40518832206726, 'box_points': [253, 194, 327, 376]}, {'name': 'backpack', 'percentage_probability': 82.40531086921692, 'box_points': [309, 157, 352, 241]}]
# Output count for unique objects :  {'person': 5, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  31
# FOR FRAME  31
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.75999593734741, 'box_points': [28, 17, 215, 448]}, {'name': 'person', 'percentage_probability': 96.75465822219849, 'box_points': [0, 138, 46, 381]}, {'name': 'person', 'percentage_probability': 99.30631518363953, 'box_points': [323, 117, 427, 403]}, {'name': 'person', 'percentage_probability': 97.72621393203735, 'box_points': [252, 192, 329, 378]}, {'name': 'backpack', 'percentage_probability': 86.65177822113037, 'box_points': [316, 152, 358, 237]}]
# Output count for unique objects :  {'person': 4, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  32
# FOR FRAME  32
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.76597428321838, 'box_points': [28, 17, 216, 448]}, {'name': 'person', 'percentage_probability': 96.70983552932739, 'box_points': [0, 138, 46, 381]}, {'name': 'person', 'percentage_probability': 99.29734468460083, 'box_points': [323, 117, 427, 403]}, {'name': 'person', 'percentage_probability': 97.78385162353516, 'box_points': [252, 192, 329, 378]}, {'name': 'backpack', 'percentage_probability': 87.24511861801147, 'box_points': [316, 152, 358, 237]}]
# Output count for unique objects :  {'person': 4, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  33
# FOR FRAME  33
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.88128542900085, 'box_points': [48, 23, 236, 459]}, {'name': 'backpack', 'percentage_probability': 82.89991021156311, 'box_points': [319, 155, 371, 250]}, {'name': 'person', 'percentage_probability': 98.28393459320068, 'box_points': [0, 134, 54, 380]}, {'name': 'person', 'percentage_probability': 99.22332763671875, 'box_points': [249, 190, 335, 369]}, {'name': 'person', 'percentage_probability': 99.79767799377441, 'box_points': [331, 113, 441, 407]}]
# Output count for unique objects :  {'person': 4, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  34
# FOR FRAME  34
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.91012215614319, 'box_points': [50, 37, 245, 456]}, {'name': 'person', 'percentage_probability': 98.26270937919617, 'box_points': [1, 131, 53, 384]}, {'name': 'person', 'percentage_probability': 99.00672435760498, 'box_points': [251, 185, 322, 373]}, {'name': 'person', 'percentage_probability': 99.65512752532959, 'box_points': [332, 114, 446, 407]}, {'name': 'skateboard', 'percentage_probability': 56.969958543777466, 'box_points': [149, 382, 270, 449]}, {'name': 'backpack', 'percentage_probability': 88.93875479698181, 'box_points': [330, 153, 371, 237]}]
# Output count for unique objects :  {'person': 4, 'skateboard': 1, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  35
# FOR FRAME  35
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.91363286972046, 'box_points': [56, 30, 267, 458]}, {'name': 'person', 'percentage_probability': 97.04593420028687, 'box_points': [2, 134, 50, 385]}, {'name': 'person', 'percentage_probability': 53.91330122947693, 'box_points': [56, 88, 167, 429]}, {'name': 'person', 'percentage_probability': 99.70600008964539, 'box_points': [251, 184, 314, 375]}, {'name': 'person', 'percentage_probability': 99.4902491569519, 'box_points': [342, 119, 457, 404]}, {'name': 'backpack', 'percentage_probability': 88.76237869262695, 'box_points': [335, 153, 376, 237]}]
# Output count for unique objects :  {'person': 5, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  36
# FOR FRAME  36
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.90586638450623, 'box_points': [61, 33, 278, 455]}, {'name': 'person', 'percentage_probability': 96.24897837638855, 'box_points': [0, 142, 52, 386]}, {'name': 'person', 'percentage_probability': 99.80359673500061, 'box_points': [245, 183, 309, 374]}, {'name': 'person', 'percentage_probability': 99.67011213302612, 'box_points': [342, 121, 473, 403]}, {'name': 'backpack', 'percentage_probability': 73.45454692840576, 'box_points': [344, 156, 384, 243]}]
# Output count for unique objects :  {'person': 4, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  37
# FOR FRAME  37
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.90400671958923, 'box_points': [60, 33, 278, 455]}, {'name': 'person', 'percentage_probability': 96.12547755241394, 'box_points': [0, 142, 52, 386]}, {'name': 'person', 'percentage_probability': 99.7991144657135, 'box_points': [245, 183, 309, 374]}, {'name': 'person', 'percentage_probability': 99.68007802963257, 'box_points': [342, 122, 473, 403]}, {'name': 'backpack', 'percentage_probability': 72.65719175338745, 'box_points': [344, 156, 384, 243]}]
# Output count for unique objects :  {'person': 4, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  38
# FOR FRAME  38
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.81930255889893, 'box_points': [51, 37, 285, 454]}, {'name': 'backpack', 'percentage_probability': 80.08515238761902, 'box_points': [349, 160, 403, 250]}, {'name': 'person', 'percentage_probability': 83.34825038909912, 'box_points': [0, 134, 45, 383]}, {'name': 'person', 'percentage_probability': 99.37180876731873, 'box_points': [238, 185, 302, 370]}, {'name': 'person', 'percentage_probability': 99.84138607978821, 'box_points': [348, 125, 488, 403]}]
# Output count for unique objects :  {'person': 4, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  39
# FOR FRAME  39
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.85814690589905, 'box_points': [61, 29, 281, 458]}, {'name': 'backpack', 'percentage_probability': 75.0901997089386, 'box_points': [357, 165, 411, 252]}, {'name': 'person', 'percentage_probability': 57.490479946136475, 'box_points': [1, 139, 47, 383]}, {'name': 'person', 'percentage_probability': 99.55607056617737, 'box_points': [237, 186, 293, 369]}, {'name': 'person', 'percentage_probability': 99.81863498687744, 'box_points': [357, 123, 513, 407]}]
# Output count for unique objects :  {'person': 4, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  40
# FOR FRAME  40
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.74877834320068, 'box_points': [68, 30, 282, 463]}, {'name': 'person', 'percentage_probability': 93.73800754547119, 'box_points': [241, 190, 291, 365]}, {'name': 'person', 'percentage_probability': 99.65531826019287, 'box_points': [364, 120, 512, 410]}, {'name': 'dog', 'percentage_probability': 87.53918409347534, 'box_points': [1, 282, 93, 377]}, {'name': 'backpack', 'percentage_probability': 86.50627136230469, 'box_points': [365, 160, 407, 244]}]
# Output count for unique objects :  {'person': 3, 'dog': 1, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  41
# FOR FRAME  41
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.10812377929688, 'box_points': [109, 29, 301, 474]}, {'name': 'person', 'percentage_probability': 99.50761198997498, 'box_points': [365, 127, 514, 401]}, {'name': 'dog', 'percentage_probability': 98.37687611579895, 'box_points': [0, 284, 90, 380]}, {'name': 'backpack', 'percentage_probability': 82.87232518196106, 'box_points': [376, 160, 416, 247]}]
# Output count for unique objects :  {'person': 2, 'dog': 1, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  42
# FOR FRAME  42
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.1342544555664, 'box_points': [109, 29, 301, 474]}, {'name': 'person', 'percentage_probability': 99.51578974723816, 'box_points': [365, 127, 514, 401]}, {'name': 'dog', 'percentage_probability': 98.38442206382751, 'box_points': [0, 284, 90, 380]}, {'name': 'backpack', 'percentage_probability': 82.80153274536133, 'box_points': [376, 160, 416, 247]}]
# Output count for unique objects :  {'person': 2, 'dog': 1, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  43
# FOR FRAME  43
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.37249422073364, 'box_points': [156, 21, 290, 438]}, {'name': 'person', 'percentage_probability': 98.7673819065094, 'box_points': [369, 128, 514, 401]}, {'name': 'dog', 'percentage_probability': 99.29001927375793, 'box_points': [0, 283, 91, 380]}, {'name': 'dog', 'percentage_probability': 88.34824562072754, 'box_points': [112, 317, 250, 447]}, {'name': 'backpack', 'percentage_probability': 86.27225756645203, 'box_points': [385, 164, 426, 246]}]
# Output count for unique objects :  {'person': 2, 'dog': 2, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  44
# FOR FRAME  44
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 83.78012180328369, 'box_points': [394, 167, 447, 251]}, {'name': 'person', 'percentage_probability': 99.77201819419861, 'box_points': [168, 41, 301, 429]}, {'name': 'person', 'percentage_probability': 98.02496433258057, 'box_points': [375, 128, 518, 400]}, {'name': 'dog', 'percentage_probability': 99.82755780220032, 'box_points': [1, 283, 99, 378]}, {'name': 'dog', 'percentage_probability': 77.05205082893372, 'box_points': [140, 324, 287, 444]}]
# Output count for unique objects :  {'backpack': 1, 'person': 2, 'dog': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  45
# FOR FRAME  45
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.81704950332642, 'box_points': [184, 21, 314, 443]}, {'name': 'person', 'percentage_probability': 93.61099004745483, 'box_points': [375, 104, 514, 390]}, {'name': 'dog', 'percentage_probability': 99.50525164604187, 'box_points': [0, 280, 112, 378]}, {'name': 'handbag', 'percentage_probability': 50.48448443412781, 'box_points': [404, 161, 442, 250]}]
# Output count for unique objects :  {'person': 2, 'dog': 1, 'handbag': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  46
# FOR FRAME  46
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.90496039390564, 'box_points': [199, 24, 333, 443]}, {'name': 'person', 'percentage_probability': 95.899099111557, 'box_points': [384, 111, 519, 390]}, {'name': 'dog', 'percentage_probability': 99.55964088439941, 'box_points': [0, 283, 117, 376]}, {'name': 'backpack', 'percentage_probability': 77.98500061035156, 'box_points': [410, 158, 450, 245]}]
# Output count for unique objects :  {'person': 2, 'dog': 1, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  47
# FOR FRAME  47
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.91021752357483, 'box_points': [199, 24, 333, 443]}, {'name': 'person', 'percentage_probability': 95.87388038635254, 'box_points': [383, 111, 520, 390]}, {'name': 'dog', 'percentage_probability': 99.57924485206604, 'box_points': [0, 283, 117, 377]}, {'name': 'backpack', 'percentage_probability': 78.53725552558899, 'box_points': [410, 158, 450, 245]}]
# Output count for unique objects :  {'person': 2, 'dog': 1, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  48
# FOR FRAME  48
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 85.0155234336853, 'box_points': [418, 161, 472, 257]}, {'name': 'person', 'percentage_probability': 99.61856603622437, 'box_points': [199, 24, 348, 445]}, {'name': 'person', 'percentage_probability': 97.23821878433228, 'box_points': [406, 129, 533, 399]}, {'name': 'dog', 'percentage_probability': 99.61423873901367, 'box_points': [0, 285, 124, 377]}]
# Output count for unique objects :  {'backpack': 1, 'person': 2, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  49
# FOR FRAME  49
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.81829524040222, 'box_points': [207, 24, 391, 470]}, {'name': 'backpack', 'percentage_probability': 85.66747903823853, 'box_points': [426, 160, 475, 252]}, {'name': 'person', 'percentage_probability': 98.59907627105713, 'box_points': [411, 123, 538, 402]}, {'name': 'person', 'percentage_probability': 97.5395143032074, 'box_points': [184, 193, 235, 375]}, {'name': 'dog', 'percentage_probability': 99.89210367202759, 'box_points': [0, 286, 138, 382]}]
# Output count for unique objects :  {'person': 3, 'backpack': 1, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  50
# FOR FRAME  50
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.95020627975464, 'box_points': [214, 32, 416, 470]}, {'name': 'person', 'percentage_probability': 97.83362746238708, 'box_points': [436, 122, 538, 405]}, {'name': 'person', 'percentage_probability': 98.52643013000488, 'box_points': [186, 198, 245, 374]}, {'name': 'dog', 'percentage_probability': 99.9070942401886, 'box_points': [1, 286, 145, 382]}, {'name': 'backpack', 'percentage_probability': 88.55949640274048, 'box_points': [432, 162, 474, 243]}]
# Output count for unique objects :  {'person': 3, 'dog': 1, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  51
# FOR FRAME  51
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.96215105056763, 'box_points': [211, 34, 422, 470]}, {'name': 'person', 'percentage_probability': 90.225750207901, 'box_points': [450, 125, 548, 401]}, {'name': 'person', 'percentage_probability': 98.8364040851593, 'box_points': [181, 190, 244, 378]}, {'name': 'dog', 'percentage_probability': 99.7837781906128, 'box_points': [6, 288, 155, 383]}, {'name': 'backpack', 'percentage_probability': 89.92418646812439, 'box_points': [440, 160, 483, 243]}, {'name': 'backpack', 'percentage_probability': 51.78634524345398, 'box_points': [207, 214, 245, 265]}]
# Output count for unique objects :  {'person': 3, 'dog': 1, 'backpack': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  52
# FOR FRAME  52
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.95895028114319, 'box_points': [210, 34, 422, 470]}, {'name': 'person', 'percentage_probability': 89.7610604763031, 'box_points': [449, 125, 548, 401]}, {'name': 'person', 'percentage_probability': 98.90068769454956, 'box_points': [181, 190, 244, 379]}, {'name': 'dog', 'percentage_probability': 99.78317618370056, 'box_points': [6, 288, 155, 383]}, {'name': 'backpack', 'percentage_probability': 89.85658288002014, 'box_points': [440, 160, 483, 243]}]
# Output count for unique objects :  {'person': 3, 'dog': 1, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  53
# FOR FRAME  53
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.96728897094727, 'box_points': [209, 34, 432, 472]}, {'name': 'backpack', 'percentage_probability': 87.9064679145813, 'box_points': [440, 158, 495, 250]}, {'name': 'person', 'percentage_probability': 96.43903374671936, 'box_points': [444, 115, 560, 391]}, {'name': 'person', 'percentage_probability': 98.76626133918762, 'box_points': [179, 189, 242, 377]}, {'name': 'dog', 'percentage_probability': 99.4429349899292, 'box_points': [19, 290, 161, 380]}, {'name': 'backpack', 'percentage_probability': 78.46652269363403, 'box_points': [207, 215, 241, 261]}]
# Output count for unique objects :  {'person': 3, 'backpack': 2, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  54
# FOR FRAME  54
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.81449246406555, 'box_points': [224, 42, 449, 475]}, {'name': 'backpack', 'percentage_probability': 83.8548481464386, 'box_points': [450, 164, 502, 253]}, {'name': 'person', 'percentage_probability': 98.3863353729248, 'box_points': [172, 186, 232, 368]}, {'name': 'person', 'percentage_probability': 98.30438494682312, 'box_points': [451, 132, 577, 403]}, {'name': 'dog', 'percentage_probability': 99.02596473693848, 'box_points': [20, 290, 167, 380]}]
# Output count for unique objects :  {'person': 3, 'backpack': 1, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  55
# FOR FRAME  55
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.89772439002991, 'box_points': [239, 37, 454, 478]}, {'name': 'backpack', 'percentage_probability': 87.89705634117126, 'box_points': [456, 163, 510, 253]}, {'name': 'person', 'percentage_probability': 99.16235208511353, 'box_points': [166, 181, 223, 371]}, {'name': 'person', 'percentage_probability': 99.55153465270996, 'box_points': [444, 128, 588, 410]}, {'name': 'dog', 'percentage_probability': 99.6144711971283, 'box_points': [32, 292, 173, 380]}]
# Output count for unique objects :  {'person': 3, 'backpack': 1, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  56
# FOR FRAME  56
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.6056616306305, 'box_points': [259, 33, 452, 476]}, {'name': 'backpack', 'percentage_probability': 90.0084376335144, 'box_points': [461, 168, 514, 248]}, {'name': 'person', 'percentage_probability': 98.08965921401978, 'box_points': [162, 180, 218, 371]}, {'name': 'person', 'percentage_probability': 98.53103756904602, 'box_points': [445, 133, 590, 402]}, {'name': 'dog', 'percentage_probability': 99.57772493362427, 'box_points': [35, 288, 180, 382]}, {'name': 'backpack', 'percentage_probability': 67.63123273849487, 'box_points': [191, 206, 224, 264]}]
# Output count for unique objects :  {'person': 3, 'backpack': 2, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  57
# FOR FRAME  57
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.59865808486938, 'box_points': [259, 33, 452, 476]}, {'name': 'backpack', 'percentage_probability': 89.78122472763062, 'box_points': [461, 168, 514, 248]}, {'name': 'person', 'percentage_probability': 98.28197956085205, 'box_points': [161, 180, 218, 370]}, {'name': 'person', 'percentage_probability': 98.53970408439636, 'box_points': [445, 134, 590, 402]}, {'name': 'dog', 'percentage_probability': 99.5680034160614, 'box_points': [35, 288, 180, 382]}, {'name': 'backpack', 'percentage_probability': 69.9688971042633, 'box_points': [191, 206, 224, 264]}]
# Output count for unique objects :  {'person': 3, 'backpack': 2, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  58
# FOR FRAME  58
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.94806051254272, 'box_points': [274, 33, 462, 478]}, {'name': 'backpack', 'percentage_probability': 91.34464263916016, 'box_points': [464, 160, 530, 253]}, {'name': 'person', 'percentage_probability': 99.15975332260132, 'box_points': [158, 177, 213, 374]}, {'name': 'person', 'percentage_probability': 99.43785071372986, 'box_points': [459, 131, 613, 402]}, {'name': 'dog', 'percentage_probability': 99.8483419418335, 'box_points': [34, 289, 183, 383]}, {'name': 'backpack', 'percentage_probability': 88.29790949821472, 'box_points': [189, 205, 220, 264]}]
# Output count for unique objects :  {'person': 3, 'backpack': 2, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  59
# FOR FRAME  59
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 83.7108314037323, 'box_points': [477, 167, 538, 258]}, {'name': 'person', 'percentage_probability': 99.54299330711365, 'box_points': [332, 34, 467, 441]}, {'name': 'person', 'percentage_probability': 99.82371926307678, 'box_points': [467, 133, 620, 404]}, {'name': 'person', 'percentage_probability': 99.55597519874573, 'box_points': [151, 185, 212, 377]}, {'name': 'dog', 'percentage_probability': 99.79965686798096, 'box_points': [33, 290, 186, 384]}, {'name': 'backpack', 'percentage_probability': 90.69892168045044, 'box_points': [185, 206, 217, 264]}]
# Output count for unique objects :  {'backpack': 2, 'person': 3, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  60
# FOR FRAME  60
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.73291158676147, 'box_points': [348, 41, 479, 429]}, {'name': 'person', 'percentage_probability': 99.85522627830505, 'box_points': [468, 132, 628, 404]}, {'name': 'person', 'percentage_probability': 96.85341715812683, 'box_points': [147, 193, 211, 374]}, {'name': 'dog', 'percentage_probability': 98.25091361999512, 'box_points': [42, 293, 191, 380]}, {'name': 'backpack', 'percentage_probability': 75.74762105941772, 'box_points': [489, 164, 535, 247]}, {'name': 'backpack', 'percentage_probability': 64.50620293617249, 'box_points': [183, 206, 217, 263]}]
# Output count for unique objects :  {'person': 3, 'dog': 1, 'backpack': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  61
# FOR FRAME  61
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.9346911907196, 'box_points': [365, 29, 501, 443]}, {'name': 'person', 'percentage_probability': 99.36741590499878, 'box_points': [471, 139, 631, 396]}, {'name': 'person', 'percentage_probability': 89.83774185180664, 'box_points': [146, 205, 211, 372]}, {'name': 'dog', 'percentage_probability': 97.79931306838989, 'box_points': [58, 294, 193, 379]}, {'name': 'backpack', 'percentage_probability': 84.07392501831055, 'box_points': [497, 164, 545, 247]}]
# Output count for unique objects :  {'person': 3, 'dog': 1, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  62
# FOR FRAME  62
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.93535876274109, 'box_points': [365, 28, 501, 443]}, {'name': 'person', 'percentage_probability': 99.36309456825256, 'box_points': [471, 139, 631, 397]}, {'name': 'person', 'percentage_probability': 90.05751013755798, 'box_points': [146, 205, 211, 372]}, {'name': 'dog', 'percentage_probability': 97.92394638061523, 'box_points': [58, 294, 194, 379]}, {'name': 'backpack', 'percentage_probability': 84.14773941040039, 'box_points': [497, 164, 545, 247]}]
# Output count for unique objects :  {'person': 3, 'dog': 1, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  63
# FOR FRAME  63
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.72305297851562, 'box_points': [372, 36, 511, 437]}, {'name': 'person', 'percentage_probability': 89.72386121749878, 'box_points': [0, 153, 45, 372]}, {'name': 'person', 'percentage_probability': 99.27934408187866, 'box_points': [498, 134, 637, 400]}, {'name': 'person', 'percentage_probability': 55.2350640296936, 'box_points': [141, 199, 207, 371]}, {'name': 'horse', 'percentage_probability': 93.65004897117615, 'box_points': [64, 288, 214, 380]}, {'name': 'backpack', 'percentage_probability': 92.67796874046326, 'box_points': [508, 164, 553, 245]}]
# Output count for unique objects :  {'person': 4, 'horse': 1, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  64
# FOR FRAME  64
# Output for each object :  [{'name': 'backpack', 'percentage_probability': 91.46943688392639, 'box_points': [512, 164, 574, 263]}, {'name': 'person', 'percentage_probability': 99.423748254776, 'box_points': [377, 41, 525, 435]}, {'name': 'person', 'percentage_probability': 87.27179169654846, 'box_points': [0, 147, 50, 381]}, {'name': 'person', 'percentage_probability': 96.04842066764832, 'box_points': [120, 188, 192, 328]}, {'name': 'person', 'percentage_probability': 99.32214021682739, 'box_points': [509, 136, 639, 401]}, {'name': 'dog', 'percentage_probability': 99.0231454372406, 'box_points': [68, 291, 219, 380]}]
# Output count for unique objects :  {'backpack': 1, 'person': 4, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  65
# FOR FRAME  65
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.87324476242065, 'box_points': [388, 43, 572, 477]}, {'name': 'backpack', 'percentage_probability': 83.18709135055542, 'box_points': [517, 165, 577, 258]}, {'name': 'person', 'percentage_probability': 93.66486072540283, 'box_points': [0, 145, 52, 386]}, {'name': 'person', 'percentage_probability': 89.00865316390991, 'box_points': [116, 186, 184, 338]}, {'name': 'person', 'percentage_probability': 98.06153178215027, 'box_points': [517, 129, 638, 409]}, {'name': 'dog', 'percentage_probability': 95.36318778991699, 'box_points': [73, 293, 227, 378]}]
# Output count for unique objects :  {'person': 4, 'backpack': 1, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  66
# FOR FRAME  66
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.95706677436829, 'box_points': [387, 42, 589, 469]}, {'name': 'person', 'percentage_probability': 93.73898506164551, 'box_points': [1, 155, 73, 386]}, {'name': 'person', 'percentage_probability': 87.19860911369324, 'box_points': [114, 185, 180, 326]}, {'name': 'person', 'percentage_probability': 97.77247309684753, 'box_points': [528, 129, 639, 410]}, {'name': 'dog', 'percentage_probability': 96.48182392120361, 'box_points': [80, 290, 233, 378]}, {'name': 'backpack', 'percentage_probability': 69.47001814842224, 'box_points': [529, 163, 576, 244]}]
# Output count for unique objects :  {'person': 4, 'dog': 1, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  67
# FOR FRAME  67
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.95608925819397, 'box_points': [387, 42, 589, 469]}, {'name': 'person', 'percentage_probability': 93.7028169631958, 'box_points': [1, 155, 73, 386]}, {'name': 'person', 'percentage_probability': 86.54571771621704, 'box_points': [115, 185, 180, 326]}, {'name': 'person', 'percentage_probability': 97.64358401298523, 'box_points': [528, 129, 639, 410]}, {'name': 'dog', 'percentage_probability': 96.32074236869812, 'box_points': [80, 290, 232, 378]}, {'name': 'backpack', 'percentage_probability': 70.05554437637329, 'box_points': [529, 163, 576, 244]}]
# Output count for unique objects :  {'person': 4, 'dog': 1, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  68
# FOR FRAME  68
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.82488751411438, 'box_points': [384, 41, 610, 470]}, {'name': 'person', 'percentage_probability': 90.30075669288635, 'box_points': [1, 157, 54, 376]}, {'name': 'person', 'percentage_probability': 97.05806970596313, 'box_points': [111, 186, 174, 333]}, {'name': 'person', 'percentage_probability': 95.68150639533997, 'box_points': [537, 124, 654, 424]}, {'name': 'dog', 'percentage_probability': 97.57429957389832, 'box_points': [81, 292, 236, 377]}, {'name': 'backpack', 'percentage_probability': 82.05922842025757, 'box_points': [539, 159, 582, 239]}]
# Output count for unique objects :  {'person': 4, 'dog': 1, 'backpack': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  69
# FOR FRAME  69
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.63206648826599, 'box_points': [386, 41, 587, 473]}, {'name': 'person', 'percentage_probability': 97.74811863899231, 'box_points': [3, 155, 76, 386]}, {'name': 'person', 'percentage_probability': 99.04890060424805, 'box_points': [109, 186, 170, 342]}, {'name': 'person', 'percentage_probability': 96.47728204727173, 'box_points': [555, 124, 658, 427]}, {'name': 'dog', 'percentage_probability': 99.64327216148376, 'box_points': [104, 286, 242, 379]}]
# Output count for unique objects :  {'person': 4, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  70
# FOR FRAME  70
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.79808330535889, 'box_points': [392, 43, 584, 488]}, {'name': 'person', 'percentage_probability': 77.15684175491333, 'box_points': [483, 37, 604, 452]}, {'name': 'person', 'percentage_probability': 98.40548634529114, 'box_points': [3, 153, 75, 381]}, {'name': 'person', 'percentage_probability': 98.87945652008057, 'box_points': [108, 185, 166, 354]}, {'name': 'person', 'percentage_probability': 96.3314414024353, 'box_points': [568, 123, 665, 428]}, {'name': 'dog', 'percentage_probability': 99.73093867301941, 'box_points': [112, 284, 244, 378]}, {'name': 'person', 'percentage_probability': 51.16901993751526, 'box_points': [415, 265, 424, 287]}]
# Output count for unique objects :  {'person': 6, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  71
# FOR FRAME  71
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.9255359172821, 'box_points': [398, 43, 580, 484]}, {'name': 'person', 'percentage_probability': 65.03279209136963, 'box_points': [484, 39, 610, 447]}, {'name': 'person', 'percentage_probability': 98.97112250328064, 'box_points': [11, 155, 90, 377]}, {'name': 'person', 'percentage_probability': 99.25808906555176, 'box_points': [101, 177, 154, 360]}, {'name': 'person', 'percentage_probability': 98.33787083625793, 'box_points': [590, 124, 680, 416]}, {'name': 'dog', 'percentage_probability': 99.51418042182922, 'box_points': [114, 288, 253, 375]}, {'name': 'person', 'percentage_probability': 61.46944761276245, 'box_points': [415, 265, 424, 288]}]
# Output count for unique objects :  {'person': 6, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  72
# FOR FRAME  72
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.93071556091309, 'box_points': [398, 44, 580, 483]}, {'name': 'person', 'percentage_probability': 64.23720717430115, 'box_points': [484, 39, 610, 447]}, {'name': 'person', 'percentage_probability': 98.9973783493042, 'box_points': [11, 155, 90, 377]}, {'name': 'person', 'percentage_probability': 99.27453994750977, 'box_points': [101, 177, 154, 360]}, {'name': 'person', 'percentage_probability': 98.30996990203857, 'box_points': [590, 125, 680, 416]}, {'name': 'dog', 'percentage_probability': 99.55507516860962, 'box_points': [114, 288, 253, 375]}, {'name': 'person', 'percentage_probability': 62.08409667015076, 'box_points': [415, 265, 424, 288]}]
# Output count for unique objects :  {'person': 6, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  73
# FOR FRAME  73
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.83862042427063, 'box_points': [414, 40, 591, 486]}, {'name': 'person', 'percentage_probability': 61.869120597839355, 'box_points': [510, 37, 631, 443]}, {'name': 'person', 'percentage_probability': 99.86110329627991, 'box_points': [13, 155, 93, 380]}, {'name': 'person', 'percentage_probability': 99.2891788482666, 'box_points': [93, 172, 149, 371]}, {'name': 'person', 'percentage_probability': 98.07679653167725, 'box_points': [598, 126, 687, 414]}, {'name': 'dog', 'percentage_probability': 99.69623684883118, 'box_points': [116, 289, 259, 377]}, {'name': 'person', 'percentage_probability': 63.66593837738037, 'box_points': [415, 264, 424, 287]}]
# Output count for unique objects :  {'person': 6, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  74
# FOR FRAME  74
# Output for each object :  [{'name': 'person', 'percentage_probability': 97.58644700050354, 'box_points': [448, 57, 643, 472]}, {'name': 'person', 'percentage_probability': 64.77344036102295, 'box_points': [532, 52, 711, 478]}, {'name': 'person', 'percentage_probability': 97.73421883583069, 'box_points': [598, 95, 703, 406]}, {'name': 'person', 'percentage_probability': 99.65301752090454, 'box_points': [11, 156, 100, 375]}, {'name': 'person', 'percentage_probability': 99.35067892074585, 'box_points': [87, 175, 146, 370]}, {'name': 'dog', 'percentage_probability': 98.59299063682556, 'box_points': [120, 288, 261, 375]}, {'name': 'person', 'percentage_probability': 61.68859601020813, 'box_points': [415, 264, 424, 287]}]
# Output count for unique objects :  {'person': 6, 'dog': 1}
# ...
# Output count for unique objects :  {'person': 2, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  153
# FOR FRAME  153
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.68681931495667, 'box_points': [450, 174, 527, 394]}, {'name': 'person', 'percentage_probability': 99.57197904586792, 'box_points': [335, 179, 396, 398]}, {'name': 'dog', 'percentage_probability': 99.44624304771423, 'box_points': [534, 302, 683, 392]}]
# Output count for unique objects :  {'person': 2, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  154
# FOR FRAME  154
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.66124892234802, 'box_points': [334, 179, 412, 390]}, {'name': 'person', 'percentage_probability': 99.22624230384827, 'box_points': [460, 180, 544, 389]}, {'name': 'dog', 'percentage_probability': 99.42960143089294, 'box_points': [552, 304, 684, 390]}]
# Output count for unique objects :  {'person': 2, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  155
# FOR FRAME  155
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.92862939834595, 'box_points': [338, 182, 427, 386]}, {'name': 'person', 'percentage_probability': 99.42343831062317, 'box_points': [467, 178, 544, 391]}, {'name': 'dog', 'percentage_probability': 99.52821135520935, 'box_points': [567, 302, 693, 394]}]
# Output count for unique objects :  {'person': 2, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  156
# FOR FRAME  156
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.95501637458801, 'box_points': [340, 187, 436, 382]}, {'name': 'person', 'percentage_probability': 99.6788740158081, 'box_points': [474, 179, 551, 392]}, {'name': 'dog', 'percentage_probability': 99.59291815757751, 'box_points': [571, 301, 701, 393]}]
# Output count for unique objects :  {'person': 2, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  157
# FOR FRAME  157
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.95506405830383, 'box_points': [340, 186, 436, 382]}, {'name': 'person', 'percentage_probability': 99.68190789222717, 'box_points': [474, 179, 551, 392]}, {'name': 'dog', 'percentage_probability': 99.58491921424866, 'box_points': [571, 301, 701, 393]}]
# Output count for unique objects :  {'person': 2, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  158
# FOR FRAME  158
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.94866847991943, 'box_points': [476, 177, 562, 390]}, {'name': 'person', 'percentage_probability': 99.93948936462402, 'box_points': [338, 189, 440, 388]}, {'name': 'dog', 'percentage_probability': 99.13406372070312, 'box_points': [579, 301, 707, 391]}]
# Output count for unique objects :  {'person': 2, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  159
# FOR FRAME  159
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.9568521976471, 'box_points': [476, 180, 566, 390]}, {'name': 'person', 'percentage_probability': 99.87040758132935, 'box_points': [337, 194, 444, 384]}, {'name': 'dog', 'percentage_probability': 99.09617304801941, 'box_points': [583, 301, 708, 390]}]
# Output count for unique objects :  {'person': 2, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  160
# FOR FRAME  160
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.92223381996155, 'box_points': [476, 186, 580, 390]}, {'name': 'person', 'percentage_probability': 99.78173971176147, 'box_points': [345, 190, 454, 393]}, {'name': 'person', 'percentage_probability': 64.49505090713501, 'box_points': [741, 140, 851, 502]}, {'name': 'dog', 'percentage_probability': 99.50718283653259, 'box_points': [585, 300, 712, 391]}]
# Output count for unique objects :  {'person': 3, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  161
# FOR FRAME  161
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.60286021232605, 'box_points': [354, 184, 449, 388]}, {'name': 'person', 'percentage_probability': 99.92507100105286, 'box_points': [478, 186, 581, 392]}, {'name': 'dog', 'percentage_probability': 99.4228184223175, 'box_points': [586, 303, 718, 389]}, {'name': 'person', 'percentage_probability': 96.31873965263367, 'box_points': [709, 182, 849, 514]}]
# Output count for unique objects :  {'person': 3, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  162
# FOR FRAME  162
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.5941162109375, 'box_points': [354, 183, 449, 388]}, {'name': 'person', 'percentage_probability': 99.92430806159973, 'box_points': [478, 186, 581, 392]}, {'name': 'dog', 'percentage_probability': 99.43347573280334, 'box_points': [586, 303, 717, 389]}, {'name': 'person', 'percentage_probability': 96.45203948020935, 'box_points': [710, 182, 849, 514]}]
# Output count for unique objects :  {'person': 3, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  163
# FOR FRAME  163
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.1300642490387, 'box_points': [368, 182, 448, 387]}, {'name': 'person', 'percentage_probability': 99.85308647155762, 'box_points': [491, 181, 580, 392]}, {'name': 'dog', 'percentage_probability': 99.10615086555481, 'box_points': [604, 303, 721, 394]}]
# Output count for unique objects :  {'person': 2, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  164
# FOR FRAME  164
# Output for each object :  [{'name': 'person', 'percentage_probability': 97.62633442878723, 'box_points': [395, 175, 451, 394]}, {'name': 'person', 'percentage_probability': 99.62083697319031, 'box_points': [512, 181, 586, 396]}, {'name': 'dog', 'percentage_probability': 98.7536370754242, 'box_points': [613, 300, 726, 393]}]
# Output count for unique objects :  {'person': 2, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  165
# FOR FRAME  165
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.3656575679779, 'box_points': [405, 169, 459, 402]}, {'name': 'person', 'percentage_probability': 97.45267629623413, 'box_points': [523, 182, 599, 398]}, {'name': 'person', 'percentage_probability': 69.16304230690002, 'box_points': [741, 86, 851, 478]}, {'name': 'dog', 'percentage_probability': 97.16008305549622, 'box_points': [617, 300, 729, 391]}]
# Output count for unique objects :  {'person': 3, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  166
# FOR FRAME  166
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.54714179039001, 'box_points': [532, 180, 599, 394]}, {'name': 'person', 'percentage_probability': 98.59327673912048, 'box_points': [716, 85, 852, 476]}, {'name': 'person', 'percentage_probability': 99.67705607414246, 'box_points': [412, 178, 467, 403]}, {'name': 'dog', 'percentage_probability': 99.01585578918457, 'box_points': [623, 298, 731, 392]}]
# Output count for unique objects :  {'person': 3, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  167
# FOR FRAME  167
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.54324960708618, 'box_points': [532, 180, 599, 394]}, {'name': 'person', 'percentage_probability': 98.54261875152588, 'box_points': [716, 83, 852, 477]}, {'name': 'person', 'percentage_probability': 99.65129494667053, 'box_points': [412, 178, 466, 402]}, {'name': 'dog', 'percentage_probability': 98.97409677505493, 'box_points': [623, 298, 731, 392]}]
# Output count for unique objects :  {'person': 3, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  168
# FOR FRAME  168
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.51420426368713, 'box_points': [417, 174, 473, 397]}, {'name': 'person', 'percentage_probability': 99.78999495506287, 'box_points': [536, 182, 612, 395]}, {'name': 'person', 'percentage_probability': 97.28938341140747, 'box_points': [718, 81, 852, 478]}, {'name': 'dog', 'percentage_probability': 99.06466603279114, 'box_points': [622, 297, 730, 391]}]
# Output count for unique objects :  {'person': 3, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  169
# FOR FRAME  169
# Output for each object :  [{'name': 'person', 'percentage_probability': 84.65036749839783, 'box_points': [703, 71, 854, 535]}, {'name': 'person', 'percentage_probability': 99.76111054420471, 'box_points': [420, 184, 488, 387]}, {'name': 'person', 'percentage_probability': 99.93081092834473, 'box_points': [539, 182, 626, 395]}, {'name': 'dog', 'percentage_probability': 98.08450937271118, 'box_points': [635, 305, 732, 387]}]
# Output count for unique objects :  {'person': 3, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  170
# FOR FRAME  170
# Output for each object :  [{'name': 'person', 'percentage_probability': 88.66328597068787, 'box_points': [694, 65, 853, 542]}, {'name': 'person', 'percentage_probability': 99.77754354476929, 'box_points': [421, 184, 504, 388]}, {'name': 'person', 'percentage_probability': 99.96752738952637, 'box_points': [538, 186, 637, 392]}, {'name': 'dog', 'percentage_probability': 92.14803576469421, 'box_points': [638, 311, 726, 388]}]
# Output count for unique objects :  {'person': 3, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  171
# FOR FRAME  171
# Output for each object :  [{'name': 'person', 'percentage_probability': 82.36868977546692, 'box_points': [677, 60, 846, 542]}, {'name': 'person', 'percentage_probability': 99.83705282211304, 'box_points': [420, 185, 509, 386]}, {'name': 'person', 'percentage_probability': 99.94282126426697, 'box_points': [543, 190, 645, 391]}, {'name': 'dog', 'percentage_probability': 90.81246852874756, 'box_points': [642, 302, 718, 380]}]
# Output count for unique objects :  {'person': 3, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  172
# FOR FRAME  172
# Output for each object :  [{'name': 'person', 'percentage_probability': 80.92429041862488, 'box_points': [677, 61, 846, 541]}, {'name': 'person', 'percentage_probability': 99.83522891998291, 'box_points': [420, 185, 509, 386]}, {'name': 'person', 'percentage_probability': 99.9410331249237, 'box_points': [543, 190, 646, 392]}, {'name': 'dog', 'percentage_probability': 91.32024049758911, 'box_points': [642, 302, 718, 380]}]
# Output count for unique objects :  {'person': 3, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  173
# FOR FRAME  173
# Output for each object :  [{'name': 'person', 'percentage_probability': 67.00073480606079, 'box_points': [652, 79, 840, 521]}, {'name': 'person', 'percentage_probability': 99.52912330627441, 'box_points': [419, 183, 514, 387]}, {'name': 'person', 'percentage_probability': 99.94465708732605, 'box_points': [540, 190, 651, 391]}]
# Output count for unique objects :  {'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  174
# FOR FRAME  174
# Output for each object :  [{'name': 'person', 'percentage_probability': 96.52870893478394, 'box_points': [420, 179, 516, 389]}, {'name': 'person', 'percentage_probability': 99.86581206321716, 'box_points': [538, 191, 654, 389]}, {'name': 'person', 'percentage_probability': 81.64502382278442, 'box_points': [639, 89, 790, 480]}]
# Output count for unique objects :  {'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  175
# FOR FRAME  175
# Output for each object :  [{'name': 'person', 'percentage_probability': 65.34643769264221, 'box_points': [611, 57, 799, 549]}, {'name': 'person', 'percentage_probability': 85.80924868583679, 'box_points': [433, 161, 519, 397]}, {'name': 'person', 'percentage_probability': 99.69788789749146, 'box_points': [546, 187, 651, 394]}]
# Output count for unique objects :  {'person': 3}
# ------------END OF A FRAME --------------
# Processing Frame :  176
# FOR FRAME  176
# Output for each object :  [{'name': 'person', 'percentage_probability': 94.80118751525879, 'box_points': [573, 62, 790, 526]}, {'name': 'person', 'percentage_probability': 88.98240923881531, 'box_points': [562, 184, 646, 389]}]
# Output count for unique objects :  {'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  177
# FOR FRAME  177
# Output for each object :  [{'name': 'person', 'percentage_probability': 95.37045955657959, 'box_points': [573, 61, 790, 526]}, {'name': 'person', 'percentage_probability': 88.90400528907776, 'box_points': [562, 184, 646, 389]}]
# Output count for unique objects :  {'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  178
# FOR FRAME  178
# Output for each object :  [{'name': 'person', 'percentage_probability': 92.83000826835632, 'box_points': [493, 70, 779, 514]}, {'name': 'person', 'percentage_probability': 55.67869544029236, 'box_points': [568, 256, 604, 324]}]
# Output count for unique objects :  {'person': 2}
# ------------END OF A FRAME --------------
# Processing Frame :  179
# FOR FRAME  179
# Output for each object :  [{'name': 'person', 'percentage_probability': 93.95900964736938, 'box_points': [513, 70, 752, 509]}, {'name': 'dog', 'percentage_probability': 74.27995204925537, 'box_points': [703, 303, 773, 383]}]
# Output count for unique objects :  {'person': 1, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  180
# FOR FRAME  180
# Output for each object :  [{'name': 'person', 'percentage_probability': 98.02703261375427, 'box_points': [514, 79, 723, 469]}, {'name': 'dog', 'percentage_probability': 79.8288345336914, 'box_points': [697, 306, 777, 384]}]
# Output count for unique objects :  {'person': 1, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  181
# FOR FRAME  181
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.08979535102844, 'box_points': [488, 71, 730, 510]}, {'name': 'dog', 'percentage_probability': 83.9320719242096, 'box_points': [690, 304, 783, 388]}]
# Output count for unique objects :  {'person': 1, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  182
# FOR FRAME  182
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.10571575164795, 'box_points': [488, 72, 729, 509]}, {'name': 'dog', 'percentage_probability': 84.34009552001953, 'box_points': [691, 304, 784, 388]}]
# Output count for unique objects :  {'person': 1, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  183
# FOR FRAME  183
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.79862570762634, 'box_points': [475, 67, 738, 535]}, {'name': 'person', 'percentage_probability': 96.35033011436462, 'box_points': [623, 197, 698, 381]}, {'name': 'dog', 'percentage_probability': 89.0697181224823, 'box_points': [695, 304, 789, 389]}]
# Output count for unique objects :  {'person': 2, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  184
# FOR FRAME  184
# Output for each object :  [{'name': 'person', 'percentage_probability': 97.92923927307129, 'box_points': [436, 42, 717, 531]}, {'name': 'person', 'percentage_probability': 99.9488115310669, 'box_points': [613, 188, 708, 391]}, {'name': 'dog', 'percentage_probability': 92.64704585075378, 'box_points': [696, 305, 794, 389]}]
# Output count for unique objects :  {'person': 2, 'dog': 1}
# ------------END OF A FRAME --------------
# Processing Frame :  185
# FOR FRAME  185
# Output for each object :  [{'name': 'person', 'percentage_probability': 99.57989454269409, 'box_points': [443, 52, 671, 530]}, {'name': 'person', 'percentage_probability': 99.96373653411865, 'box_points': [613, 190, 714, 393]}, {'name': 'dog', 'percentage_probability': 90.62070846557617, 'box_points': [706, 307, 796, 388]}]
# Output count for unique objects :  {'person': 2, 'dog': 1}
# ------------END OF A FRAME --------------

# %%
video_path
# Out:
# 'output_video.avi'
